# %%
# !pip install -q langchain_google_genai PyPDF2 langchain llama-index llama-hub pypdf
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.7/817.7 kB 20.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.9/103.9 MB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 18.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.3/299.3 kB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 38.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.0/116.0 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 43.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 47.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 2.4 MB/s eta 0:00:00
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI


llm=ChatGoogleGenerativeAI(model="gemini-1.5-pro-latest",google_api_key="AIzaSyABvNrYchqdvOUMl9fsvA32ksRC-2nQff0")

# %%
service_context = ServiceContext.from_defaults(llm=llm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4fb69e362f82> in <cell line: 1>()
# ----> 1 service_context = ServiceContext.from_defaults(llm=llm)
#
# NameError: name 'ServiceContext' is not defined

# %%
results=llm.invoke("write about srilanka")
results.content
# Out:
# '## Sri Lanka: The Pearl of the Indian Ocean \n\nSri Lanka, aptly nicknamed the "Pearl of the Indian Ocean," is a vibrant island nation boasting incredible diversity within its relatively small size. From pristine beaches and lush rainforests to ancient ruins and bustling cities, Sri Lanka offers a unique and unforgettable experience for every traveler. \n\n**Here\'s a glimpse of what makes Sri Lanka so special:**\n\n**Natural Beauty:**\n\n* **Beaches:** Sri Lanka is renowned for its stunning coastline, with palm-fringed beaches like Bentota, Mirissa, and Unawatuna offering golden sands, turquoise waters, and excellent opportunities for swimming, surfing, and sunbathing.\n* **Hill Country:** The central highlands boast rolling hills carpeted with tea plantations, cascading waterfalls, and charming colonial towns like Nuwara Eliya, often referred to as "Little England." \n* **Wildlife:** Sri Lanka is a haven for wildlife enthusiasts. National parks like Yala and Udawalawe are home to 
# ...

# %%
from llama_index.core import SimpleDirectoryReader, ServiceContext, VectorStoreIndex

# %%
from llama_index.core.tools  import QueryEngineTool, ToolMetadata
from llama_index.core.query_engine import SubQuestionQueryEngine

# %%
pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.7/817.7 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 14.7 MB/s eta 0:00:00
# ...

# %%
pip install -q PyPDF2 langchain

# %%
import PyPDF2
import os

# Path to the PDF file in the sample data folder
file_path = '/3.5 Release Notes Red Hat Software Collections 3 _ Red Hat Customer Portal (1).pdf'

# Check if the file exists
if os.path.exists(file_path):
    with open(file_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ''
        for page in range(len(reader.pages)):
            text += reader.pages[page].extract_text()
else:
    print("File not found!")

# Now 'text' variable contains the content of the PDF file
print(text)
# Out:
# Jump To Close
# Expand all  Collapse all
# Table of contents
# 1. 3.5 Release Notes
# 2. 1. Red Hat Software Collections 3.5
# i. 1.1. About Red Hat Software Collections
# i. 1.1.1. Red Hat Developer Toolset
# ii. 1.2. Main Features
# iii. 1.3. Changes in Red Hat Software Collections 3.5
# i. 1.3.1. Overview
# ii. 1.3.2. Changes in Red Hat Developer Toolset
# iii. 1.3.3. Changes in Perl
# iv. 1.3.4. Changes in Python
# v. 1.3.5. Changes in Ruby
# vi. 1.3.6. Changes in Apache httpd
# vii. 1.3.7. Changes in V arnish Cache
# viii. 1.3.8. Changes in JDK Mission Control
# ix. 1.3.9. Changes in HAProxy
# iv. 1.4. Compatibility Information
# v. 1.5. Known Issues
# vi. 1.6. Deprecated Functionality
# 3. 2. Installation
# i. 2.1. Getting Access to Red Hat Software Collections
# i. 2.1.1. Using Red Hat Subscription Management
# ii. 2.1.2. Packages from the Optional Repository
# ii. 2.2. Installing Red Hat Software Collections
# i. 2.2.1. Installing Individual Software Collections
# ...

# %%
text
# Out:
# 'Jump To Close\nExpand all  Collapse all\nTable of contents\n1. 3.5 Release Notes\n2. 1. Red Hat Software Collections 3.5 \ni. 1.1. About Red Hat Software Collections \ni. 1.1.1. Red Hat Developer Toolset\nii. 1.2. Main Features\niii. 1.3. Changes in Red Hat Software Collections 3.5 \ni. 1.3.1. Overview\nii. 1.3.2. Changes in Red Hat Developer Toolset\niii. 1.3.3. Changes in Perl\niv. 1.3.4. Changes in Python\nv. 1.3.5. Changes in Ruby\nvi. 1.3.6. Changes in Apache httpd\nvii. 1.3.7. Changes in V arnish Cache\nviii. 1.3.8. Changes in JDK Mission Control\nix. 1.3.9. Changes in HAProxy\niv. 1.4. Compatibility Information\nv. 1.5. Known Issues\nvi. 1.6. Deprecated Functionality\n3. 2. Installation \ni. 2.1. Getting Access to Red Hat Software Collections \ni. 2.1.1. Using Red Hat Subscription Management\nii. 2.1.2. Packages from the Optional Repository\nii. 2.2. Installing Red Hat Software Collections \ni. 2.2.1. Installing Individual Software Collections\nii. 2.2.2. Installing Optional 
# ...

# %%
reader = SimpleDirectoryReader(
    input_files=["/3.5 Release Notes Red Hat Software Collections 3 _ Red Hat Customer Portal (1).pdf"]
)

# %%
docs = reader.load_data()

# %%
index=VectorStoreIndex.from_documents(docs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/llama_index/core/embeddings/utils.py in resolve_embed_model(embed_model, callback_manager)
#      58             embed_model = OpenAIEmbedding()
# ---> 59             validate_openai_api_key(embed_model.api_key)
#      60         except ImportError:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/embeddings/openai/utils.py in validate_openai_api_key(api_key)
#     103     if not openai_api_key:
# --> 104         raise ValueError(MISSING_API_KEY_ERROR_MESSAGE)
#
# ValueError: No API key found for OpenAI.
# Please set either the OPENAI_API_KEY environment variable or openai.api_key prior to initialization.
# API keys can be found or created at https://platform.openai.com/account/api-keys
#
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
from llama_index.core import SummaryIndex

# %%
index=SummaryIndex.from_documents(docs)

# %%
pip install -q llama-index-llms-langchain

# %%
base_engine=index.as_query_engine(similarity_top_k=4,llm=llm)

# %%
res=base_engine.query("what is this document about ?")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f262fb1b5469> in <cell line: 1>()
# ----> 1 res=base_engine.query("what is this document about ?")
#
# NameError: name 'base_engine' is not defined

# %%
from llama_index.core import SimpleDirectoryReader, ServiceContext, VectorStoreIndex

from llama_index.core.tools  import QueryEngineTool, ToolMetadata
from llama_index.core.query_engine import SubQuestionQueryEngine

# %%
pip install llama-index-llms-langchain

# %%
#service_context = ServiceContext.from_defaults(llm=llm)
# Out:
# <ipython-input-7-4fb69e362f82>:1: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(llm=llm)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/llama_index/core/embeddings/utils.py in resolve_embed_model(embed_model, callback_manager)
#      58             embed_model = OpenAIEmbedding()
# ---> 59             validate_openai_api_key(embed_model.api_key)
#      60         except ImportError:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/embeddings/openai/utils.py in validate_openai_api_key(api_key)
#     103     if not openai_api_key:
# --> 104         raise ValueError(MISSING_API_KEY_ERROR_MESSAGE)
#
# ValueError: No API key found for OpenAI.
# ...

# %%
# !wget https://www.dropbox.com/s/qctkz6nxhm0y5qe/lyft_2021.pdf?dl=1 -O lyft_2021.pdf
# !wget https://www.dropbox.com/s/te0a2w227v27iag/uber_2021.pdf?dl=1 -O uber_2021.pdf
# Out:
# --2024-04-28 12:15:51--  https://www.dropbox.com/s/qctkz6nxhm0y5qe/lyft_2021.pdf?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/qctkz6nxhm0y5qe/lyft_2021.pdf [following]
# --2024-04-28 12:15:51--  https://www.dropbox.com/s/dl/qctkz6nxhm0y5qe/lyft_2021.pdf
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc604707336ff485654cb26b6c46.dl.dropboxusercontent.com/cd/0/get/CR4xubGn76sjZJGQuVMzi6khLrMpnm51GW5AT_xoOiS5FVvz2SU2AFyRPGSQb9BeJs6wmWZw2_CHVPJcLxI2WI8-Rmh5WB9JHW3Pi18RiY1D3m6om6P6rMCWMzZxHGRWmCjN_SpWUFQ0qayfJ3yd0Tj7/file?dl=1# [following]
# ...

# %%
lyft_docs = SimpleDirectoryReader(input_files=["lyft_2021.pdf"]).load_data()
uber_docs = SimpleDirectoryReader(input_files=["uber_2021.pdf"]).load_data()

# %%
print(lyft_docs[0].get_content())
# Out:
# UNITED STATESSECURITIES AND EXCHANGE COMMISSION
# Washington, D.C. 20549
# FORM 10-K
#
# (Mark One)
# ☒
# ANNUAL REPORT PURS UANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934For the fiscal year ended December 31, 2021
# OR
# ☐
# TRANSITION REPORT PURS UANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934 FOR THE TRANSITION PERIODFROM                      TO
# Commission File Number 001-38846
# Lyft, Inc.
# (Exact name of Registrant as specified in i
# ts Charter)Delaware
# 20-8809830 (State or other jurisdiction of
# incorporation or organization)
# (I.R.S. EmployerIdentification No.)
# 185 Berry Street, Suite 5000
# San Francisco, California
# 94107 (Address of principal executive offices)
# (Zip Code) Registrant’s telephone number, including area code: (844) 250
# -2773Securities registered pursuant to Section 12(b) of the Act:
# Title of each class
# TradingSymbol(s)
# ...

# %%
from llama_index.core import SummaryIndex


index=SummaryIndex.from_documents(lyft_docs + uber_docs)

# %%
pip install -q chromadb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.8/526.8 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 15.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.9/91.9 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 31.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 7.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 kB 42.9 MB/s eta 0:00:00
# ...

# %%
pip install -q llama-index-embeddings-gemini
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 598.7/598.7 kB 8.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-google-genai 1.0.2 requires google-generativeai<0.6.0,>=0.5.0, but you have google-generativeai 0.4.1 which is incompatible.

# %%
pip install llama-index-vector-stores-chroma
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.5/525.5 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.9/91.9 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 22.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 35.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
pip install llama_index.vector_stores
# Out:
# ERROR: Could not find a version that satisfies the requirement llama_index.vector_stores (from versions: none)
# ERROR: No matching distribution found for llama_index.vector_stores

# %%
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
from llama_index.core import Document
from llama_index.core import Settings
from llama_index.core import SimpleDirectoryReader
from llama_index.core import StorageContext
from llama_index.core import VectorStoreIndex
#from llama_index.readers.web import SimpleWebPageReader

from llama_index.vector_stores.chroma import ChromaVectorStore

import chromadb
import re

# %%
pip install llama-index-llms-langchain

# %%
# %pip install -q llama-index-embeddings-gemini
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 598.7/598.7 kB 6.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-google-genai 1.0.3 requires google-generativeai<0.6.0,>=0.5.2, but you have google-generativeai 0.4.1 which is incompatible.

# %%
from llama_index.embeddings.gemini import GeminiEmbedding

gemini_embedding_model = GeminiEmbedding(api_key="AIzaSyABvNrYchqdvOUMl9fsvA32ksRC-2nQff0", model_name="models/embedding-001")

# %%
# Create a client and a new collection
client = chromadb.PersistentClient(path="./chroma_db")
chroma_collection = client.get_or_create_collection("quickstart")

# Create a vector store
vector_store = ChromaVectorStore(chroma_collection=chroma_collection)

# Create a storage context
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# Set Global settings
Settings.llm = llm
Settings.embed_model = gemini_embedding_model

# Create an index from the documents and save it to the disk.
index = VectorStoreIndex.from_documents(
    lyft_docs + uber_docs, storage_context=storage_context
)

# %%
# setup baseline index#
#base_index = VectorStoreIndex.from_documents(lyft_docs + uber_docs)
base_engine = index.as_query_engine(similarity_top_k=4)

# %%
response = base_engine.query("What are some risk factors for Uber?")
print(str(response))
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `BaseChatModel.predict_messages` was deprecated in langchain-core 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ## Uber's Risk Factors: A Summary
#
# Based on the provided text, Uber faces a multitude of risks across different aspects of its business. Here's a breakdown of some key areas:
#
# **Technology and Security:**
#
# * **Cyberattacks:**  With vast amounts of user data, Uber is a prime target for cyberattacks. Despite security measures, breaches could lead to reputational damage, financial losses, and regulatory issues.
# * **System Failures:** The complexity of Uber's platform makes it susceptible to bugs, errors, and downtime. Outages and technical issues could negatively impact user experience and platform reliability, driving users away.
# ...

# %%
response = base_engine.query("Compare and contrast the risk factors of Uber and Lyft?")
print(str(response))
# Out:
# I am sorry, but I cannot answer your query. The context provided discusses Lyft's risk factors, but does not mention any information about Uber or its risk factors. To compare and contrast the risk factors of Uber and Lyft, I would need information on the risk factors of both companies.

# %%
lyft_index = VectorStoreIndex.from_documents(lyft_docs)

# %%
uber_index = VectorStoreIndex.from_documents(uber_docs)

# %%
lyft_engine = lyft_index.as_query_engine(similarity_top_k=2)

# %%
uber_engine = uber_index.as_query_engine(similarity_top_k=2)

# %%
query_engine_tools = [
    QueryEngineTool(
        query_engine=lyft_engine,
        metadata=ToolMetadata(
            name="lyft_10k",
            description="Provides information about Lyft financials for year 2021",
        ),
    ),
    QueryEngineTool(
        query_engine=uber_engine,
        metadata=ToolMetadata(
            name="uber_10k",
            description="Provides information about Uber financials for year 2021",
        ),
    ),
]

s_engine = SubQuestionQueryEngine.from_defaults(query_engine_tools=query_engine_tools)

# %%
response = s_engine.query("Compare and contrast the risk factors of Uber and Lyft?")
# Out:
# Generated 2 sub questions.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-33-dab44a8703a1> in <cell line: 1>()
# ----> 1 response = s_engine.query("Compare and contrast the risk factors of Uber and Lyft?")
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     272             )
#     273             try:
# --> 274                 result = func(*args, **kwargs)
#     275             except BaseException as e:
#     276                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/base/base_query_engine.py in query(self, str_or_query_bundle)
#      51             if isinstance(str_or_query_bundle, str):
#      52                 str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ...
